# %%
# %matplotlib inline
import projectile_motion
projectile_motion.plot_projectile_motion(20, [15, 30, 45, 60, 75])
plt.show()
# Out:
# Traceback (most recent call last):
#
#   File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 2
#     import projectile_motion
#
#   File /workspaces/solutions_repo/docs/1 Physics/1 Mechanics/projectile_motion.py:1
#     %matplotlib inline
#     ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
import projectile_motion
projectile_motion.plot_projectile_motion(20, [15, 30, 45, 60, 75])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 import projectile_motion
#       3 projectile_motion.plot_projectile_motion(20, [15, 30, 45, 60, 75])
# ----> 4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import projectile_motion
projectile_motion.plot_projectile_motion(20, [15, 30, 45, 60, 75])
plt.show()
